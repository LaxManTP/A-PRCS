# %%
######################
## A-PRCS

## Anti
## Poaching
## Response 
## Companion
## System
######################

import numpy as np                      ## 
import cv2                              ##
import ultralytics
from ultralytics import YOLO      ## you only look once model
from ultralytics import solutions ## 


ultralytics.checks()              ## checks for running correctly

# %%
## YOLO OBJECT RECOGNITION

model = YOLO('yolo26n.pt')     ## pre trained YOLO nano model import

## train model on buffalo, elephant, rhino, and zebra
results = model.train(data="african-wildlife.yaml", epochs=100, imgsz=640)
## train model on custom elements like people, weapons, and drones
results = model.train()
